# %%
import numpy as np

# %%
a=np.array([10,20,30,40,50])
print(a)
# Out:
# [10 20 30 40 50]

# %%
print(np.zeros(5))
# Out:
# [0. 0. 0. 0. 0.]

# %%
print(np.zeros((2,3)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(np.ones(5))
# Out:
# [1. 1. 1. 1. 1.]

# %%
print(np.arange(1,10))
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
print(np.arange(0,21,3))
# Out:
# [ 0  3  6  9 12 15 18]

# %%
print(np.random.rand(5))
# Out:
# [0.74783743 0.67209118 0.54314839 0.07063379 0.08838405]

# %%
print(np.random.randint(1,50,5))
# Out:
# [21 49 30 21 15]

# %%
p=np.array([[1,2,3],[4,5,6]])
print(p)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(p.shape)
# Out:
# (2, 3)

# %%
print(p.ndim)
# Out:
# 2

# %%
print(p.size)
# Out:
# 6

# %%
print(p.dtype)
# Out:
# int64

# %%
q=p.reshape(3,2)
print(q)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
a=np.array([10,20,30])
b=np.array([4,5,6])

print(a+b)
print(a-b)
print(a*b)
# Out:
# [14 25 36]
# [ 6 15 24]
# [ 40 100 180]

# %%
r=np.array([10,20,30,40,50])
print(np.sum(r))
# Out:
# 150

# %%
print(np.mean(r))
# Out:
# 30.0

# %%
print(np.median(r))
# Out:
# 30.0

# %%
print(np.std(r))
# Out:
# 14.142135623730951

# %%
print(np.var(r))
# Out:
# 200.0

# %%
print(np.min(r))
# Out:
# 10

# %%
print(np.max(r))
# Out:
# 50

# %%
print(p.T)
# Out:
# [1 2 3 4 5 6]
