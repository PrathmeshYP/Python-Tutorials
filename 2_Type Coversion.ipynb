# %%
#Implicit Type Conversion
a=12
b=15.6
sum=a+b
print(sum)
print(type(a))
print(type(b))
print(type(sum))
# Out:
# 27.6
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
#Explicit Type Conversion
x=12
y="12"
z=int(y)
sum=x+z
print(sum)
# Out:
# 24
