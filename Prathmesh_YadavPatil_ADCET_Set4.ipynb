# %% [markdown]
# # 1)Check if a given number is positive, negative, or zero.

# %%
a=int(input("Enter a number : "))
if a==0:
    if a>0:
        print("Number is Positive")
    else :
        print("Number is zero")
else:
    print("Number is negative")
# Out:
# Enter a number :  0
# Number is zero

# %% [markdown]
# # 2) Take age from the user and print “Eligible to vote” if age >= 18.

# %%
age=int(input("Enter your age : "))
if age>=18:
    print("Youre elligible for voting")
else:
    print("Youre not elligible for voting")
# Out:
# Enter your age :  23
# Youre elligible for voting

# %% [markdown]
# # 3) Take two numbers and print which one is greater.

# %%
a=int(input("Enter first number : "))
b=int(input("Enter second number : "))
if a>b:
    print(a," is greater than ",b)
else:
    print(b," is greater than ",a)
# Out:
# Enter first number :  20
# Enter second number :  30
# 30  is greater than  20

# %% [markdown]
# # 4) Check if a number is even or odd.

# %%
a=int(input("Enter a number : "))
if a%2==0:
    print(a," is even ")
else:
    print(a," is odd")
# Out:
# Enter a number :  3
# 3  is odd

# %% [markdown]
# # 5) Check if a given year is a leap year or not.

# %%
year=int(input("Enter year : "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("leap year")
else:
    print("Not a leap year")
# Out:
# Enter year :  2026
# Not a leap year

# %% [markdown]
# # 6) Take temperature and print “Hot” if > 30, otherwise print “Normal”

# %%
temp=int(input("Enter temperature"))
if temp>30:
    print("Temperature is hot")
else:
    temp("Temp is normal")
# Out:
# Enter temperature 44
# Temperature is hot

# %% [markdown]
# # 7)Print the largest of three numbers.

# %%
a=int(input("Enter first number : "))
b=int(input("Enter second number : "))
c=int(input("Enter third number : "))
if a>b and a>c:
    print(a," is greater")
elif b>a and b>c:
    print(b," is greater")
else:
    print(c," is greater")
# Out:
# Enter first number :  10
# Enter second number :  20
# Enter third number :  30
# 30  is greater

# %% [markdown]
# # 8) Take student marks and print pass/fail (pass = above 35).

# %%
marks=int(input("Enter marks : "))
if marks >35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks :  80
# Pass

# %% [markdown]
# # 9) Check if a given character is a vowel or consonant.

# %%
char=input("Enter a character : ").lower()
if char in 'a,e,i,o,u':
    print("It is vowel")
else:
    print("It is consonant")
# Out:
# Enter a character :  f
# It is consonant

# %% [markdown]
# #  10)Take length and breadth and check if it is a square or not

# %%
length=int(input("Enter length : "))
breadth=int(input("Enter Breadth : "))
if length==breadth:
    print("It is a square")
else:
    print("It is not square")
# Out:
# Enter length :  5
# Enter Breadth :  5
# It is a square
