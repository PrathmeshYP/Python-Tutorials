# %%
import pandas as pd

# %%
df=pd.read_csv("Hospital_Patient_Data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of     Patient_ID    Name   Age  Gender   Department Doctor_Name Admission_Date  \
# 0        P0001   Pooja  48.0       M  Orthopedics   Dr. Patil     09-04-2024
# 1        P0002   Rahul   NaN       F   Cardiology   Dr. Singh     09-08-2024
# 2        P0003   Pooja   NaN       M    Neurology    Dr. Khan     29-09-2024
# 3        P0004   Rohan  52.0       F   Cardiology     Dr. Rao     08-06-2024
# 4        P0005   Kiran  56.0       M     Oncology   Dr. Patil     13-06-2024
# ..         ...     ...   ...     ...          ...         ...            ...
# 965      P0684   Pooja   NaN  Femael   Pediatrics    Dr. Khan     25-03-2024
# 966      P0102   Vikas  16.0  Female    Neurology   Dr. Patil     02-01-2024
# 967      P0783   Rahul  47.0       M   Cardiology    Dr. Khan     01-03-2024
# 968      P0836   Priya  20.0  Female    Neurology  Dr. Sharma     07-04-2024
# 969      P0095  Anjali  19.0       M  Orthopedics  Dr. Sharma     21-10-2024
#
# ...

# %%
df.head(10)
# Out:
#   Patient_ID    Name   Age  Gender   Department Doctor_Name Admission_Date  \
# 0      P0001   Pooja  48.0       M  Orthopedics   Dr. Patil     09-04-2024
# 1      P0002   Rahul   NaN       F   Cardiology   Dr. Singh     09-08-2024
# 2      P0003   Pooja   NaN       M    Neurology    Dr. Khan     29-09-2024
# 3      P0004   Rohan  52.0       F   Cardiology     Dr. Rao     08-06-2024
# 4      P0005   Kiran  56.0       M     Oncology   Dr. Patil     13-06-2024
# 5      P0006   Vikas   NaN    Male  Orthopedics   Dr. Mehta     12-03-2024
# 6      P0007   Priya   NaN       F    Neurology   Dr. Patil     28-09-2024
# 7      P0008  Anjali   NaN  Femael  Orthopedics   Dr. Mehta     29-05-2024
# 8      P0009   Vikas  33.0  Femael   Cardiology   Dr. Patil     18-04-2024
# 9      P0010   Sneha   2.0       M    Neurology     Dr. Rao     27-02-2024
#
#   Discharge_Date       Diagnosis  Treatment_Cost Payment_Mode Room_Type  \
# ...

# %%
df.tail()
# Out:
#     Patient_ID    Name   Age  Gender   Department Doctor_Name Admission_Date  \
# 965      P0684   Pooja   NaN  Femael   Pediatrics    Dr. Khan     25-03-2024
# 966      P0102   Vikas  16.0  Female    Neurology   Dr. Patil     02-01-2024
# 967      P0783   Rahul  47.0       M   Cardiology    Dr. Khan     01-03-2024
# 968      P0836   Priya  20.0  Female    Neurology  Dr. Sharma     07-04-2024
# 969      P0095  Anjali  19.0       M  Orthopedics  Dr. Sharma     21-10-2024
#
#     Discharge_Date Diagnosis  Treatment_Cost Payment_Mode Room_Type     City  \
# 965     26-03-2024       NaN               0    Insurance   Private  Solapur
# 966     07-01-2024    Cancer          131507        Cashh      Semi   Mumbai
# 967     07-03-2024       NaN               0         UPI       semi   Mumbai
# 968     12-04-2024       NaN          999999          UPI      Semi   Nagpur
# 969     31-10-2024    Asthma               0          UPI   General     Pune
#
#     Feedback
# 965   averge
# ...

# %%
df.tail(5)
# Out:
#     Patient_ID    Name   Age  Gender   Department Doctor_Name Admission_Date  \
# 965      P0684   Pooja   NaN  Femael   Pediatrics    Dr. Khan     25-03-2024
# 966      P0102   Vikas  16.0  Female    Neurology   Dr. Patil     02-01-2024
# 967      P0783   Rahul  47.0       M   Cardiology    Dr. Khan     01-03-2024
# 968      P0836   Priya  20.0  Female    Neurology  Dr. Sharma     07-04-2024
# 969      P0095  Anjali  19.0       M  Orthopedics  Dr. Sharma     21-10-2024
#
#     Discharge_Date Diagnosis  Treatment_Cost Payment_Mode Room_Type     City  \
# 965     26-03-2024       NaN               0    Insurance   Private  Solapur
# 966     07-01-2024    Cancer          131507        Cashh      Semi   Mumbai
# 967     07-03-2024       NaN               0         UPI       semi   Mumbai
# 968     12-04-2024       NaN          999999          UPI      Semi   Nagpur
# 969     31-10-2024    Asthma               0          UPI   General     Pune
#
#     Feedback
# 965   averge
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      970 non-null    object
#  1   Name            970 non-null    object
#  2   Age             514 non-null    float64
#  3   Gender          970 non-null    object
#  4   Department      970 non-null    object
#  5   Doctor_Name     970 non-null    object
#  6   Admission_Date  970 non-null    object
#  7   Discharge_Date  970 non-null    object
#  8   Diagnosis       504 non-null    object
#  9   Treatment_Cost  970 non-null    int64
#  10  Payment_Mode    970 non-null    object
#  11  Room_Type       970 non-null    object
#  12  City            970 non-null    object
#  13  Feedback        822 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 106.2+ KB

# %%
df.describe()
# Out:
#               Age  Treatment_Cost
# count  514.000000      970.000000
# mean    45.550584   336971.670103
# std     25.566227   446723.976568
# min      1.000000        0.000000
# 25%     24.250000        0.000000
# 50%     46.000000    72719.500000
# 75%     68.000000   999999.000000
# max     90.000000   999999.000000

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Name', 'Age', 'Gender', 'Department', 'Doctor_Name',
#        'Admission_Date', 'Discharge_Date', 'Diagnosis', 'Treatment_Cost',
#        'Payment_Mode', 'Room_Type', 'City', 'Feedback'],
#       dtype='object')

# %%
df["Age"]
# Out:
# 0      48.0
# 1       NaN
# 2       NaN
# 3      52.0
# 4      56.0
#        ...
# 965     NaN
# 966    16.0
# 967    47.0
# 968    20.0
# 969    19.0
# Name: Age, Length: 970, dtype: float64

# %%
df[["Patient_ID","Age","Gender","Treatment_Cost"]]
# Out:
#     Patient_ID   Age  Gender  Treatment_Cost
# 0        P0001  48.0       M               0
# 1        P0002   NaN       F           89123
# 2        P0003   NaN       M               0
# 3        P0004  52.0       F           14448
# 4        P0005  56.0       M           84306
# ..         ...   ...     ...             ...
# 965      P0684   NaN  Femael               0
# 966      P0102  16.0  Female          131507
# 967      P0783  47.0       M               0
# 968      P0836  20.0  Female          999999
# 969      P0095  19.0       M               0
#
# [970 rows x 4 columns]

# %% [markdown]
# # DATA CLEANING

# %%
df.isnull().sum
#if data is missing or having null value it shows true
# Out:
# <bound method DataFrame.sum of      Patient_ID   Name    Age  Gender  Department  Doctor_Name  \
# 0         False  False  False   False       False        False
# 1         False  False   True   False       False        False
# 2         False  False   True   False       False        False
# 3         False  False  False   False       False        False
# 4         False  False  False   False       False        False
# ..          ...    ...    ...     ...         ...          ...
# 965       False  False   True   False       False        False
# 966       False  False  False   False       False        False
# 967       False  False  False   False       False        False
# 968       False  False  False   False       False        False
# 969       False  False  False   False       False        False
#
#      Admission_Date  Discharge_Date  Diagnosis  Treatment_Cost  Payment_Mode  \
# 0             False           False      False           False         False
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID          0
# Name                0
# Age               456
# Gender              0
# Department          0
# Doctor_Name         0
# Admission_Date      0
# Discharge_Date      0
# Diagnosis         466
# Treatment_Cost      0
# Payment_Mode        0
# Room_Type           0
# City                0
# Feedback          148
# dtype: int64

# %%
#fill null value
df["Age"].fillna(df["Age"].mean(),inplace=True)
df.head()
# Out:
#   Patient_ID   Name        Age Gender   Department Doctor_Name Admission_Date  \
# 0      P0001  Pooja  48.000000      M  Orthopedics   Dr. Patil     09-04-2024
# 1      P0002  Rahul  45.550584      F   Cardiology   Dr. Singh     09-08-2024
# 2      P0003  Pooja  45.550584      M    Neurology    Dr. Khan     29-09-2024
# 3      P0004  Rohan  52.000000      F   Cardiology     Dr. Rao     08-06-2024
# 4      P0005  Kiran  56.000000      M     Oncology   Dr. Patil     13-06-2024
#
#   Discharge_Date       Diagnosis  Treatment_Cost Payment_Mode Room_Type  \
# 0     13-04-2024          Cancer               0         UPI    General
# 1     17-08-2024   Heart Disease           89123         Cash   Private
# 2     08-10-2024  Skin Infection               0          UPI   Generel
# 3     17-06-2024             NaN           14448    Insurance   Private
# 4     14-06-2024             NaN           84306          UPI   Private
#
#          City Feedback
# 0    Kolhapur   averge
# ...

# %%
df.dropna(subset=["Condition"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19208\3684067198.py in ?()
# ----> 1 df.dropna(subset=["Condition"])
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6673             ax = self._get_axis(agg_axis)
#    6674             indices = ax.get_indexer_for(subset)
#    6675             check = indices == -1
#    6676             if check.any():
# -> 6677                 raise KeyError(np.array(subset)[check].tolist())
#    6678             agg_obj = self.take(indices, axis=agg_axis)
#    6679
#    6680         if thresh is not lib.no_default:
#
# KeyError: ['Condition']

# %%
df["Gender"]= df["Gender"].replace({"Male":"M","Female":"F"})

# %%
df
# Out:
#     Patient_ID    Name        Age  Gender   Department Doctor_Name  \
# 0        P0001   Pooja  48.000000       M  Orthopedics   Dr. Patil
# 1        P0002   Rahul  45.550584       F   Cardiology   Dr. Singh
# 2        P0003   Pooja  45.550584       M    Neurology    Dr. Khan
# 3        P0004   Rohan  52.000000       F   Cardiology     Dr. Rao
# 4        P0005   Kiran  56.000000       M     Oncology   Dr. Patil
# ..         ...     ...        ...     ...          ...         ...
# 965      P0684   Pooja  45.550584  Femael   Pediatrics    Dr. Khan
# 966      P0102   Vikas  16.000000       F    Neurology   Dr. Patil
# 967      P0783   Rahul  47.000000       M   Cardiology    Dr. Khan
# 968      P0836   Priya  20.000000       F    Neurology  Dr. Sharma
# 969      P0095  Anjali  19.000000       M  Orthopedics  Dr. Sharma
#
#     Admission_Date Discharge_Date       Diagnosis  Treatment_Cost  \
# 0       09-04-2024     13-04-2024          Cancer               0
# ...
