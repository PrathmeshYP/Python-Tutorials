# %% [markdown]
# # Tuple

# %%
tup=(10,20,30,40)
print(tup)
# Out:
# (10, 20, 30, 40)

# %%
print(tup[0])
# Out:
# 10

# %%
print(tup[1:])
# Out:
# (20, 30, 40)

# %%
print(tup.count(30))
# Out:
# 1

# %%
print(len(tup))
# Out:
# 4

# %%
print(tup.index(40))
# Out:
# 3

# %%
print(20 in tup)
print(50 not in tup)
# Out:
# True
# True
